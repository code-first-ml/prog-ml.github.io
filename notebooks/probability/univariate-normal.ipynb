# %%
import torch
import matplotlib.pyplot as plt
import seaborn as sns
sns.reset_defaults()
sns.set_context(context="talk", font_scale=1)
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

import matplotlib as mpl

mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.top'] = False

# %%
dist = torch.distributions

# %%
normal = dist.Normal(loc = 0., scale = 1.)
normal
# Out:
# Normal(loc: 0.0, scale: 1.0)

# %% [markdown]
# ### Drawing samples

# %%
sample = normal.sample([1000])

# %%
sns.displot(sample)

# %%
sns.displot(sample, kind='kde',bw_adjust=2, rug=True)

# %%
sns.displot(sample, kind='ecdf')

# %%
normal.log_prob(torch.tensor([1.]))
# Out:
# tensor([-1.4189])

# %% [markdown]
# ### Finding pdf at a given point

# %%
x = torch.linspace(-5., 5., 100)

pdf_x = normal.log_prob(x).exp()

# %%
plt.plot(x, pdf_x)
plt.xlabel("x")
plt.ylabel("PDF")
# Out:
# Text(0, 0.5, 'PDF')

# %% [markdown]
# ### Finding cdf at a given point

# %%
plt.plot(x, normal.cdf(x))

# %%
### 

normal.enumerate_support()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Input In [46], in <module>
#       1 ###
# ----> 3 normal.enumerate_support()
#
# File ~/miniforge3/lib/python3.9/site-packages/torch/distributions/distribution.py:216, in Distribution.enumerate_support(self, expand)
#     194 def enumerate_support(self, expand=True):
#     195     """
#     196     Returns tensor containing all values supported by a discrete
#     197     distribution. The result will enumerate over dimension 0, so the shape
#    (...)
#     214         Tensor iterating over dimension 0.
#     215     """
# --> 216     raise NotImplementedError
#
# NotImplementedError:

# %%
dist.Bernoulli(0.5).enumerate_support()
# Out:
# tensor([0., 1.])

# %%
import tensorflow_probability as tfp
tfd = tfp.distributions

t = tfd.Normal(0., 1.)

# %%
t.entropy()
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=1.4189385>

# %%
e = tfd.Bernoulli(0.5)
e.

# %%
[x for x in dir(normal) if "__" not in x]
# Out:
# ['_batch_shape',
#  '_event_shape',
#  '_extended_shape',
#  '_get_checked_instance',
#  '_log_normalizer',
#  '_mean_carrier_measure',
#  '_natural_params',
#  '_validate_args',
#  '_validate_sample',
#  'arg_constraints',
#  'batch_shape',
#  'cdf',
#  'entropy',
#  'enumerate_support',
#  'event_shape',
#  'expand',
#  'has_enumerate_support',
#  'has_rsample',
#  'icdf',
#  'loc',
#  'log_prob',
#  'mean',
#  'perplexity',
#  'rsample',
#  'sample',
#  'sample_n',
#  'scale',
#  'set_default_validate_args',
#  'stddev',
#  'support',
#  'variance']

# %%
normal.has_enumerate_support
# Out:
# False

# %%
normal.mean
# Out:
# tensor(0.)

# %%
normal.support
# Out:
# Real()

# %%
normal.arg_constraints
# Out:
# {'loc': Real(), 'scale': GreaterThan(lower_bound=0.0)}

# %%
normal.entropy()
# Out:
# tensor(1.4189)

# %%
dist.Normal(1., 1).entropy()
# Out:
# tensor(1.4189)

# %%
dist.Normal(1., 2).entropy()
# Out:
# tensor(2.1121)

# %%
normal.stddev
# Out:
# tensor(1.)

# %%
normal.variance
# Out:
# tensor(1.)

# %%
normal.perplexity()
# Out:
# tensor(4.1327)

# %%
normal._validate_args
# Out:
# True

# %%
normal._mean_carrier_measure
# Out:
# 0
